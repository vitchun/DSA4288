# %% [markdown]
# ### Function Approximation Big Idea
#
# So far, the states represented are finite and as such, it is possible for us to keep a Q-table (or dictionary) that stores the Q-value of each state. However, this becomes practically impossible if the number of states is very large or we havef a continuous state. One example would be the position and velocity of a car moving up a mountain - the state, represented by the position (x,y coodinate) and velocity of the car are continuous and the number of states is basically infinite. Hence, in such problem, we cannot use a Q-table to store the Q-value.
#
# Therefore, we use a function, parameterized by $\mathbb{w}$ to approximate the Q-value of all the states. This function can be a linear function (taking the form of $Q(s,a; \mathbb{w}) = \mathbb{w}^T \phi(s,a)$) or a (deep) neural network. Here, we represent our states using a feature vector $\phi(s,a)$.
#
# The key idea is that instead of memorizing the Q-value for every possible state-action pair, we learn a mapping that generalizes across similar states. For example, if two states share similar features (say the car is moving slowly uphill in both cases), the function approximation allows us to assign similar Q-values without having to visit and store both states explicitly. This generalization is what makes function approximation powerful in large or continuous environments (but can also be hard to find a good function that can approximate q-values correctly for all states)

# %% [markdown]
# ### Update rule
#
# Recall that in standard Q-learning with discrete states, the update rule is:
#
# $$
# Q(s,a) \leftarrow Q(s,a)+α[r+\gamma \max_{a'} Q(s′,a′)−Q(s,a)]
# $$
#
# When we use function approximation, we replace the Q-table with a parameterized function $Q(s, a; \mathbf{w})$, where $\mathbf{w}$ are the parameters (weights) we need to learn.Therefore, the goal is to find parameters $\mathbf{w}$ that minimize the difference between the current Q-value estimate and the target Q-value.
#
# The temporal difference (TD) error for a transition $(s, a, r, s')$ is:
#
# $$
# \delta =r+\gamma \max_{a'} Q(s′,a′;w)−Q(s,a;w))
# $$
#
# Instead of updating a table entry, we now update the parameters $\mathbf{w}$ to reduce this error. Specifically, we want to optimize $\mathbf{w}$ to make $Q(s, a; \mathbf{w})$ closer to the target $r + \gamma \max_{a'} Q(s', a'; \mathbf{w})$.
#
# One way to do that is to use Gradient Descent (or variants of it). The loss function for a single sample is:
#
# $$
# L(w)=\frac{1}{2}[r+\gamma \max_{a'} Q(s′,a′;w)−Q(s,a;w)]^2
# $$
#
# The gradient of this loss with respect to $\mathbf{w}$ is:
#
# $$
# \nabla_w L(w)= −[r+\gamma \max_{a'} Q(s′,a′;w)−Q(s,a;w)]\nabla_wQ(s,a;w)
# $$
#
# Therefore, the update rule for the parameters is:
# $$
# w\leftarrow w−\alpha\nabla_wL(w)
# $$
#
# where $\alpha$ is the learning rate.

# %%
#pip install gymnax

# %%
import jax
import jax.numpy as jnp
import optax
import gymnax

# %%
env, env_params = gymnax.make("CartPole-v1")
rng = jax.random.PRNGKey(0)
obs, state = env.reset(rng, env_params)

# %%
def rbf_features(x, centers, sigma=0.5):
    # x: (d,), centers: (n_centers, d)
    diffs = x - centers  # (n_centers, d)
    sq_dist = jnp.sum(diffs**2, axis=-1)
    return jnp.exp(-sq_dist / (2 * sigma**2))  # (n_centers,)

def init_params(rng, n_features, n_actions):
    W = jax.random.normal(rng, (n_features, n_actions)) * 0.1
    return W

def q_values(W, obs, centers, sigma=0.5):
    phi = rbf_features(obs, centers, sigma)  # (n_features,)
    return phi @ W  # (n_actions,)

# epsilon greedy
def select_action(W, obs, rng, centers, sigma=0.5, epsilon=0.1):
    q = q_values(W, obs, centers, sigma)
    greedy = jnp.argmax(q)
    explore = jax.random.bernoulli(rng, epsilon)
    return jnp.where(explore, jax.random.randint(rng, (), 0, q.shape[0]), greedy)

# TD loss (Q-learning)
def td_loss(W, obs, action, reward, next_obs, done, gamma, centers, sigma):
    q = q_values(W, obs, centers, sigma)[action]
    next_q = jnp.max(q_values(W, next_obs, centers, sigma))
    target = reward + gamma * (1 - done) * next_q
    return 0.5 * (q - target) ** 2

# %%
def train(num_episodes=500, lr=1e-2, gamma=0.99, n_centers=50, sigma=0.5):
    obs_dim = env.observation_space(env_params).shape[0]
    n_actions = env.action_space(env_params).n

    rng = jax.random.PRNGKey(0)
    rng, centers_rng, init_rng = jax.random.split(rng, 3)

    # Random RBF centers sampled from [-1,1]
    centers = jax.random.uniform(centers_rng, (n_centers, obs_dim), minval=-1, maxval=1)

    W = init_params(init_rng, n_centers, n_actions)
    opt = optax.sgd(lr)
    opt_state = opt.init(W)

    @jax.jit
    def update(W, opt_state, obs, action, reward, next_obs, done, rng):
        loss_fn = lambda p: td_loss(p, obs, action, reward, next_obs, done, gamma, centers, sigma)
        grads = jax.grad(loss_fn)(W)
        updates, opt_state = opt.update(grads, opt_state, W)
        W = optax.apply_updates(W, updates)
        return W, opt_state

    for ep in range(num_episodes):
        rng, ep_rng = jax.random.split(rng)
        obs, state = env.reset(ep_rng, env_params)
        done = False
        ep_reward = 0.0

        while not done:
            rng, act_rng = jax.random.split(rng)
            action = select_action(W, obs, act_rng, centers, sigma)
            next_obs, state, reward, done, _ = env.step(act_rng, state, action, env_params)

            W, opt_state = update(W, opt_state, obs, action, reward, next_obs, done, rng)
            obs = next_obs
            ep_reward += reward

        print(f"Episode {ep}, reward: {ep_reward:.1f}")

    return W, centers

# %%
train()
# Out:
# Episode 0, reward: 17.0
# Episode 1, reward: 19.0
# Episode 2, reward: 14.0
# Episode 3, reward: 22.0
# Episode 4, reward: 20.0
# Episode 5, reward: 21.0
# Episode 6, reward: 16.0
# Episode 7, reward: 21.0
# Episode 8, reward: 27.0
# Episode 9, reward: 23.0
# Episode 10, reward: 21.0
# Episode 11, reward: 26.0
# Episode 12, reward: 23.0
# Episode 13, reward: 23.0
# Episode 14, reward: 29.0
# Episode 15, reward: 38.0
# Episode 16, reward: 10.0
# Episode 17, reward: 11.0
# Episode 18, reward: 10.0
# Episode 19, reward: 21.0
# Episode 20, reward: 23.0
# Episode 21, reward: 23.0
# Episode 22, reward: 28.0
# Episode 23, reward: 27.0
# Episode 24, reward: 26.0
# Episode 25, reward: 19.0
# Episode 26, reward: 20.0
# Episode 27, reward: 19.0
# Episode 28, reward: 30.0
# Episode 29, reward: 25.0
# Episode 30, reward: 29.0
# Episode 31, reward: 31.0
# Episode 32, reward: 42.0
# Episode 33, reward: 79.0
# Episode 34, reward: 41.0
# Episode 35, reward: 49.0
# Episode 36, reward: 25.0
# Episode 37, reward: 54.0
# Episode 38, reward: 24.0
# Episode 39, reward: 27.0
# Episode 40, reward: 60.0
# Episode 41, reward: 38.0
# Episode 42, reward: 59.0
# Episode 43, reward: 11.0
# Episode 44, reward: 11.0
# Episode 45, reward: 28.0
# Episode 46, reward: 52.0
# Episode 47, reward: 30.0
# Episode 48, reward: 14.0
# Episode 49, reward: 21.0
# Episode 50, reward: 26.0
# Episode 51, reward: 21.0
# Episode 52, reward: 18.0
# Episode 53, reward: 18.0
# Episode 54, reward: 15.0
# Episode 55, reward: 17.0
# Episode 56, reward: 31.0
# Episode 57, reward: 10.0
# Episode 58, reward: 18.0
# Episode 59, reward: 18.0
# Episode 60, reward: 9.0
# Episode 61, reward: 9.0
# Episode 62, reward: 8.0
# Episode 63, reward: 9.0
# Episode 64, reward: 9.0
# Episode 65, reward: 9.0
# Episode 66, reward: 9.0
# Episode 67, reward: 12.0
# Episode 68, reward: 9.0
# Episode 69, reward: 10.0
# Episode 70, reward: 12.0
# Episode 71, reward: 9.0
# Episode 72, reward: 9.0
# Episode 73, reward: 19.0
# Episode 74, reward: 12.0
# Episode 75, reward: 11.0
# Episode 76, reward: 12.0
# Episode 77, reward: 8.0
# Episode 78, reward: 9.0
# Episode 79, reward: 10.0
# Episode 80, reward: 12.0
# Episode 81, reward: 8.0
# Episode 82, reward: 9.0
# Episode 83, reward: 12.0
# Episode 84, reward: 11.0
# Episode 85, reward: 11.0
# Episode 86, reward: 10.0
# Episode 87, reward: 9.0
# Episode 88, reward: 9.0
# Episode 89, reward: 16.0
# Episode 90, reward: 10.0
# Episode 91, reward: 12.0
# Episode 92, reward: 17.0
# Episode 93, reward: 9.0
# Episode 94, reward: 11.0
# Episode 95, reward: 13.0
# Episode 96, reward: 9.0
# Episode 97, reward: 9.0
# Episode 98, reward: 11.0
# Episode 99, reward: 10.0
# Episode 100, reward: 11.0
# Episode 101, reward: 10.0
# Episode 102, reward: 9.0
# Episode 103, reward: 16.0
# Episode 104, reward: 17.0
# Episode 105, reward: 15.0
# Episode 106, reward: 13.0
# Episode 107, reward: 8.0
# Episode 108, reward: 11.0
# Episode 109, reward: 11.0
# Episode 110, reward: 10.0
# Episode 111, reward: 21.0
# Episode 112, reward: 20.0
# Episode 113, reward: 29.0
# Episode 114, reward: 53.0
# Episode 115, reward: 75.0
# Episode 116, reward: 105.0
# Episode 117, reward: 76.0
# Episode 118, reward: 71.0
# Episode 119, reward: 72.0
# Episode 120, reward: 90.0
# Episode 121, reward: 500.0
# Episode 122, reward: 73.0
# Episode 123, reward: 46.0
# Episode 124, reward: 99.0
# Episode 125, reward: 75.0
# Episode 126, reward: 104.0
# Episode 127, reward: 73.0
# Episode 128, reward: 78.0
# Episode 129, reward: 58.0
# Episode 130, reward: 70.0
# Episode 131, reward: 77.0
# Episode 132, reward: 123.0
# Episode 133, reward: 71.0
# Episode 134, reward: 58.0
# Episode 135, reward: 95.0
# Episode 136, reward: 11.0
# Episode 137, reward: 500.0
# Episode 138, reward: 27.0
# Episode 139, reward: 372.0
# Episode 140, reward: 43.0
# Episode 141, reward: 83.0
# Episode 142, reward: 20.0
# Episode 143, reward: 15.0
# Episode 144, reward: 67.0
# Episode 145, reward: 110.0
# Episode 146, reward: 69.0
# Episode 147, reward: 76.0
# Episode 148, reward: 68.0
# Episode 149, reward: 48.0
# Episode 150, reward: 124.0
# Episode 151, reward: 180.0
# Episode 152, reward: 12.0
# Episode 153, reward: 150.0
# Episode 154, reward: 106.0
# Episode 155, reward: 56.0
# Episode 156, reward: 500.0
# Episode 157, reward: 23.0
# Episode 158, reward: 19.0
# Episode 159, reward: 208.0
# Episode 160, reward: 70.0
# Episode 161, reward: 19.0
# Episode 162, reward: 19.0
# Episode 163, reward: 125.0
# Episode 164, reward: 34.0
# Episode 165, reward: 86.0
# Episode 166, reward: 56.0
# Episode 167, reward: 209.0
# Episode 168, reward: 10.0
# Episode 169, reward: 9.0
# Episode 170, reward: 9.0
# Episode 171, reward: 9.0
# Episode 172, reward: 8.0
# Episode 173, reward: 38.0
# Episode 174, reward: 12.0
# Episode 175, reward: 9.0
# Episode 176, reward: 10.0
# Episode 177, reward: 9.0
# Episode 178, reward: 9.0
# Episode 179, reward: 11.0
# Episode 180, reward: 10.0
# Episode 181, reward: 9.0
# Episode 182, reward: 9.0
# Episode 183, reward: 10.0
# Episode 184, reward: 41.0
# Episode 185, reward: 10.0
# Episode 186, reward: 9.0
# Episode 187, reward: 8.0
# Episode 188, reward: 9.0
# Episode 189, reward: 10.0
# Episode 190, reward: 10.0
# Episode 191, reward: 10.0
# Episode 192, reward: 10.0
# Episode 193, reward: 9.0
# Episode 194, reward: 20.0
# Episode 195, reward: 12.0
# Episode 196, reward: 12.0
# Episode 197, reward: 9.0
# Episode 198, reward: 8.0
# Episode 199, reward: 10.0
# Episode 200, reward: 10.0
# Episode 201, reward: 10.0
# Episode 202, reward: 10.0
# Episode 203, reward: 9.0
# Episode 204, reward: 11.0
# Episode 205, reward: 11.0
# Episode 206, reward: 10.0
# Episode 207, reward: 9.0
# Episode 208, reward: 12.0
# Episode 209, reward: 10.0
# Episode 210, reward: 10.0
# Episode 211, reward: 11.0
# Episode 212, reward: 11.0
# Episode 213, reward: 9.0
# Episode 214, reward: 10.0
# Episode 215, reward: 8.0
# Episode 216, reward: 9.0
# Episode 217, reward: 13.0
# Episode 218, reward: 9.0
# Episode 219, reward: 10.0
# Episode 220, reward: 11.0
# Episode 221, reward: 8.0
# Episode 222, reward: 10.0
# Episode 223, reward: 10.0
# Episode 224, reward: 9.0
# Episode 225, reward: 9.0
# Episode 226, reward: 9.0
# Episode 227, reward: 9.0
# Episode 228, reward: 9.0
# Episode 229, reward: 9.0
# Episode 230, reward: 10.0
# Episode 231, reward: 11.0
# Episode 232, reward: 9.0
# Episode 233, reward: 9.0
# Episode 234, reward: 10.0
# Episode 235, reward: 8.0
# Episode 236, reward: 9.0
# Episode 237, reward: 10.0
# Episode 238, reward: 9.0
# Episode 239, reward: 9.0
# Episode 240, reward: 14.0
# Episode 241, reward: 9.0
# Episode 242, reward: 8.0
# Episode 243, reward: 9.0
# Episode 244, reward: 8.0
# Episode 245, reward: 10.0
# Episode 246, reward: 10.0
# Episode 247, reward: 9.0
# Episode 248, reward: 10.0
# Episode 249, reward: 8.0
# Episode 250, reward: 10.0
# Episode 251, reward: 11.0
# Episode 252, reward: 9.0
# Episode 253, reward: 10.0
# Episode 254, reward: 9.0
# Episode 255, reward: 10.0
# Episode 256, reward: 10.0
# Episode 257, reward: 9.0
# Episode 258, reward: 10.0
# Episode 259, reward: 10.0
# Episode 260, reward: 10.0
# Episode 261, reward: 10.0
# Episode 262, reward: 10.0
# Episode 263, reward: 10.0
# Episode 264, reward: 9.0
# Episode 265, reward: 9.0
# Episode 266, reward: 9.0
# Episode 267, reward: 9.0
# Episode 268, reward: 10.0
# Episode 269, reward: 9.0
# Episode 270, reward: 11.0
# Episode 271, reward: 9.0
# Episode 272, reward: 10.0
# Episode 273, reward: 13.0
# Episode 274, reward: 9.0
# Episode 275, reward: 11.0
# Episode 276, reward: 11.0
# Episode 277, reward: 10.0
# Episode 278, reward: 10.0
# Episode 279, reward: 11.0
# Episode 280, reward: 9.0
# Episode 281, reward: 13.0
# Episode 282, reward: 11.0
# Episode 283, reward: 10.0
# Episode 284, reward: 12.0
# Episode 285, reward: 10.0
# Episode 286, reward: 9.0
# Episode 287, reward: 11.0
# Episode 288, reward: 9.0
# Episode 289, reward: 11.0
# Episode 290, reward: 9.0
# Episode 291, reward: 13.0
# Episode 292, reward: 10.0
# Episode 293, reward: 10.0
# Episode 294, reward: 9.0
# Episode 295, reward: 10.0
# Episode 296, reward: 10.0
# Episode 297, reward: 9.0
# Episode 298, reward: 9.0
# Episode 299, reward: 10.0
# Episode 300, reward: 9.0
# Episode 301, reward: 9.0
# Episode 302, reward: 10.0
# Episode 303, reward: 9.0
# Episode 304, reward: 10.0
# Episode 305, reward: 10.0
# Episode 306, reward: 10.0
# Episode 307, reward: 10.0
# Episode 308, reward: 9.0
# Episode 309, reward: 10.0
# Episode 310, reward: 10.0
# Episode 311, reward: 8.0
# Episode 312, reward: 10.0
# Episode 313, reward: 10.0
# Episode 314, reward: 10.0
# Episode 315, reward: 10.0
# Episode 316, reward: 11.0
# Episode 317, reward: 14.0
# Episode 318, reward: 9.0
# Episode 319, reward: 9.0
# Episode 320, reward: 12.0
# Episode 321, reward: 10.0
# Episode 322, reward: 8.0
# Episode 323, reward: 11.0
# Episode 324, reward: 9.0
# Episode 325, reward: 10.0
# Episode 326, reward: 9.0
# Episode 327, reward: 10.0
# Episode 328, reward: 10.0
# Episode 329, reward: 9.0
# Episode 330, reward: 10.0
# Episode 331, reward: 9.0
# Episode 332, reward: 12.0
# Episode 333, reward: 12.0
# Episode 334, reward: 13.0
# Episode 335, reward: 14.0
# Episode 336, reward: 14.0
# Episode 337, reward: 17.0
# Episode 338, reward: 19.0
# Episode 339, reward: 18.0
# Episode 340, reward: 28.0
# Episode 341, reward: 22.0
# Episode 342, reward: 20.0
# Episode 343, reward: 44.0
# Episode 344, reward: 45.0
# Episode 345, reward: 135.0
# Episode 346, reward: 47.0
# Episode 347, reward: 53.0
# Episode 348, reward: 30.0
# Episode 349, reward: 50.0
# Episode 350, reward: 35.0
# Episode 351, reward: 45.0
# Episode 352, reward: 42.0
# Episode 353, reward: 38.0
# Episode 354, reward: 69.0
# Episode 355, reward: 54.0
# Episode 356, reward: 51.0
# Episode 357, reward: 50.0
# Episode 358, reward: 96.0
# Episode 359, reward: 131.0
# Episode 360, reward: 49.0
# Episode 361, reward: 59.0
# Episode 362, reward: 48.0
# Episode 363, reward: 35.0
# Episode 364, reward: 66.0
# Episode 365, reward: 63.0
# Episode 366, reward: 73.0
# Episode 367, reward: 160.0
# Episode 368, reward: 42.0
# Episode 369, reward: 94.0
# Episode 370, reward: 167.0
# Episode 371, reward: 49.0
# Episode 372, reward: 212.0
# Episode 373, reward: 73.0
# Episode 374, reward: 58.0
# Episode 375, reward: 65.0
# Episode 376, reward: 172.0
# Episode 377, reward: 85.0
# Episode 378, reward: 70.0
# Episode 379, reward: 160.0
# Episode 380, reward: 177.0
# Episode 381, reward: 61.0
# Episode 382, reward: 88.0
# Episode 383, reward: 81.0
# Episode 384, reward: 227.0
# Episode 385, reward: 75.0
# Episode 386, reward: 93.0
# Episode 387, reward: 119.0
# Episode 388, reward: 121.0
# Episode 389, reward: 128.0
# Episode 390, reward: 146.0
# Episode 391, reward: 61.0
# Episode 392, reward: 125.0
# Episode 393, reward: 83.0
# Episode 394, reward: 73.0
# Episode 395, reward: 71.0
# Episode 396, reward: 51.0
# Episode 397, reward: 280.0
# Episode 398, reward: 65.0
# Episode 399, reward: 110.0
# Episode 400, reward: 63.0
# Episode 401, reward: 500.0
# Episode 402, reward: 151.0
# Episode 403, reward: 257.0
# Episode 404, reward: 107.0
# Episode 405, reward: 105.0
# Episode 406, reward: 88.0
# Episode 407, reward: 92.0
# Episode 408, reward: 322.0
# Episode 409, reward: 78.0
# Episode 410, reward: 53.0
# Episode 411, reward: 65.0
# Episode 412, reward: 89.0
# Episode 413, reward: 74.0
# Episode 414, reward: 94.0
# Episode 415, reward: 247.0
# Episode 416, reward: 254.0
# Episode 417, reward: 498.0
# Episode 418, reward: 140.0
# Episode 419, reward: 401.0
# Episode 420, reward: 230.0
# Episode 421, reward: 144.0
# Episode 422, reward: 102.0
# Episode 423, reward: 132.0
# Episode 424, reward: 249.0
# Episode 425, reward: 74.0
# Episode 426, reward: 72.0
# Episode 427, reward: 95.0
# Episode 428, reward: 96.0
# Episode 429, reward: 235.0
# Episode 430, reward: 142.0
# Episode 431, reward: 75.0
# Episode 432, reward: 54.0
# Episode 433, reward: 247.0
# Episode 434, reward: 113.0
# Episode 435, reward: 47.0
# Episode 436, reward: 76.0
# Episode 437, reward: 71.0
# Episode 438, reward: 66.0
# Episode 439, reward: 123.0
# Episode 440, reward: 63.0
# Episode 441, reward: 169.0
# Episode 442, reward: 61.0
# Episode 443, reward: 66.0
# Episode 444, reward: 224.0
# Episode 445, reward: 64.0
# Episode 446, reward: 197.0
# Episode 447, reward: 71.0
# Episode 448, reward: 50.0
# Episode 449, reward: 51.0
# Episode 450, reward: 44.0
# Episode 451, reward: 51.0
# Episode 452, reward: 74.0
# Episode 453, reward: 90.0
# Episode 454, reward: 210.0
# Episode 455, reward: 137.0
# Episode 456, reward: 273.0
# Episode 457, reward: 133.0
# Episode 458, reward: 231.0
# Episode 459, reward: 83.0
# Episode 460, reward: 169.0
# Episode 461, reward: 88.0
# Episode 462, reward: 128.0
# Episode 463, reward: 143.0
# Episode 464, reward: 226.0
# Episode 465, reward: 416.0
# Episode 466, reward: 199.0
# Episode 467, reward: 119.0
# Episode 468, reward: 166.0
# Episode 469, reward: 337.0
# Episode 470, reward: 213.0
# Episode 471, reward: 92.0
# Episode 472, reward: 65.0
# Episode 473, reward: 80.0
# Episode 474, reward: 120.0
# Episode 475, reward: 170.0
# Episode 476, reward: 70.0
# Episode 477, reward: 310.0
# Episode 478, reward: 232.0
# Episode 479, reward: 180.0
# Episode 480, reward: 150.0
# Episode 481, reward: 83.0
# Episode 482, reward: 46.0
# Episode 483, reward: 69.0
# Episode 484, reward: 80.0
# Episode 485, reward: 80.0
# Episode 486, reward: 72.0
# Episode 487, reward: 96.0
# Episode 488, reward: 66.0
# Episode 489, reward: 210.0
# Episode 490, reward: 500.0
# Episode 491, reward: 83.0
# Episode 492, reward: 101.0
# Episode 493, reward: 224.0
# Episode 494, reward: 78.0
# Episode 495, reward: 60.0
# Episode 496, reward: 193.0
# Episode 497, reward: 262.0
# Episode 498, reward: 263.0
# Episode 499, reward: 121.0
# (Array([[ 0.23053566, -0.07308456],
#         [ 0.20252419,  0.00577167],
#         [-0.04803572,  0.01652985],
#         [ 0.5268843 , -0.04535921],
#         [ 0.15910895, -0.04975554],
#         [-0.06341079,  0.24048017],
#         [ 0.08211395,  0.24280427],
#         [ 0.70962745,  0.49221927],
#         [ 0.50684416,  0.24370238],
#         [ 0.1339713 , -0.02061459],
#         [-0.03336898, -0.1947515 ],
#         [-0.03958366,  0.18594886],
#         [ 0.76393896,  0.9209299 ],
#         [-0.00718571,  0.21688199],
#         [ 0.13983637, -0.23056711],
#         [-0.2383598 ,  0.09403404],
#         [-0.00434367,  0.02627548],
#         [ 0.1793421 ,  0.03034162],
#         [ 0.28782344,  0.57183343],
#         [ 0.3927906 ,  0.19313508],
#         [ 0.06950882, -0.03123685],
#         [ 0.1913739 ,  0.06651889],
#         [ 0.47488075,  0.3558313 ],
#         [ 0.40317017,  0.18110329],
#         [ 0.03161961,  0.01166398],
#         [ 0.25133145,  0.10042507],
#         [-0.03300701,  0.25252035],
#         [ 0.02113672,  0.13472155],
#         [ 0.25248808,  0.08537529],
#         [ 1.0960101 ,  0.7535524 ],
#         [ 0.08906639,  0.38159755],
#         [ 0.2119044 ,  0.15390237],
#         [-0.03287099, -0.22010265],
#         [ 0.05416706, -0.06298736],
#         [-0.05367208,  0.16710351],
#         [ 0.13405561,  0.5807429 ],
#         [ 0.11131898,  0.14216274],
#         [ 0.5547611 , -0.1074579 ],
#         [ 0.40910175,  0.40057826],
#         [ 0.20202817,  0.52109456],
#         [ 0.20575806,  0.09045573],
#         [ 0.17735395,  0.22884192],
#         [ 0.19233015,  0.20295024],
#         [ 0.2033301 ,  0.27951393],
#         [ 0.12543759,  0.12795675],
#         [ 0.04767225, -0.14549698],
#         [ 0.27454302,  0.32599133],
#         [-0.14738527,  0.01133959],
#         [ 0.55380434,  0.07300169],
#         [ 0.5004622 ,  0.4841726 ]], dtype=float32),
#  Array([[-0.98541236, -0.9582176 ,  0.162853  , -0.27632403],
#         [-0.55392456, -0.76142335, -0.74912214,  0.23365998],
#         [-0.8099854 ,  0.96684504, -0.15035582,  0.66496015],
#         [-0.8067758 , -0.5459583 , -0.2908504 ,  0.34208274],
#         [-0.7660713 , -0.05521393, -0.6609576 , -0.9498596 ],
#         [-0.731271  , -0.25255132,  0.8165903 ,  0.5833442 ],
#         [-0.7534721 , -0.41303635,  0.58081174,  0.9019952 ],
#         [-0.31768775,  0.0429759 , -0.48326612, -0.9228716 ],
#         [-0.16752648,  0.64369607, -0.8060143 , -0.5253153 ],
#         [-0.98371387, -0.906476  , -0.36152768, -0.9136474 ],
#         [-0.953269  , -0.9012048 , -0.21626067, -0.52784085],
#         [ 0.3057196 , -0.65333176,  0.94471526,  0.4222679 ],
#         [-0.06306148,  0.5569658 ,  0.64031243, -0.7424264 ],
#         [ 0.51005006, -0.8304317 ,  0.14754796, -0.89133024],
#         [-0.3646505 ,  0.38304925, -0.54606843,  0.66702867],
#         [-0.24249148,  0.01521111,  0.7091117 ,  0.64946795],
#         [ 0.91170835,  0.5554509 ,  0.8442147 , -0.74090624],
#         [ 0.45850444,  0.48217607, -0.7821648 ,  0.7959714 ],
#         [-0.00322294, -0.08467174,  0.01418066,  0.51972437],
#         [ 0.42939854, -0.1655705 , -0.32116032,  0.5273857 ],
#         [-0.8972893 ,  0.42939186, -0.6666608 , -0.00486064],
#         [-0.43976378,  0.83835053, -0.9057567 ,  0.7294586 ],
#         [-0.5242393 ,  0.28872132, -0.54622483,  0.07073712],
#         [ 0.05328321,  0.07215762, -0.13122463,  0.5090978 ],
#         [-0.4974668 ,  0.16418076, -0.8071284 ,  0.5892997 ],
#         [ 0.38349128,  0.45100045, -0.6515591 ,  0.3061595 ],
#         [-0.64796925, -0.04186034,  0.46459723,  0.81307435],
#         [ 0.4749534 , -0.7608683 , -0.9630296 ,  0.3504107 ],
#         [-0.6699636 ,  0.00440955, -0.4584999 , -0.14272642],
#         [-0.07971334,  0.86206937, -0.25792217, -0.78619385],
#         [-0.42393255, -0.08039761,  0.7496023 , -0.2875185 ],
#         [-0.38831735, -0.5856459 ,  0.5336335 ,  0.09377098],
#         [-0.10698724,  0.38379073, -0.5697408 ,  0.83312845],
#         [-0.9267943 ,  0.3404796 ,  0.0451324 ,  0.8445189 ],
#         [-0.85784197,  0.385839  , -0.15246677,  0.5086682 ],
#         [ 0.15262628,  0.56531286,  0.82478285,  0.0821321 ],
#         [-0.78464746, -0.5398047 , -0.8508873 ,  0.63313794],
#         [-0.10372925, -0.02839708, -0.9002614 , -0.05847692],
#         [-0.78539634,  0.49876451, -0.19357705, -0.03768945],
#         [-0.2294755 , -0.3587563 ,  0.4021721 , -0.05565739],
#         [ 0.00623131,  0.47236943, -0.6423178 ,  0.41462636],
#         [ 0.45300698, -0.43321705, -0.99679065,  0.64324236],
#         [ 0.5358715 , -0.46270466,  0.34483933, -0.19758296],
#         [-0.75037265,  0.15716314, -0.33223796,  0.10922122],
#         [ 0.93914247, -0.8758147 , -0.7653818 ,  0.49083805],
#         [-0.84419274,  0.7248206 ,  0.1061306 ,  0.91385627],
#         [ 0.3076179 , -0.09741426,  0.7311604 , -0.14220214],
#         [-0.7544081 ,  0.06869555,  0.689275  ,  0.5421839 ],
#         [ 0.7098429 ,  0.2419033 , -0.58586645, -0.3385601 ],
#         [ 0.42892075, -0.3445816 ,  0.24488068, -0.22252274]],      dtype=float32))
